# %%
from collections import deque
queue = deque()

print('시작')

while True:
    # 메뉴 프린트
    # 메뉴 번호 입력
    menu = int(input('>>'))
    
    if menu == 0: break
    elif menu == 1: # enqueue
        data = int(input('데이터 :'))
        queue. append(data)
    elif menu == 2: # dequeue
        if queue:
            data = queue. popleft ()
            print('가져온 데이터 :', data)
        else:
            print('Queue가 비어 있습니다')
    elif menu == 3: # peek
            if queue:
                print(queue[0])
            else:
                print('Queue가 비어 있습니다')
print('종료')
# Out:
# 시작
# >> 1
# 데이터 : 3
# >> 2
# 가져온 데이터 : 3
# >> 5
# >> 3
# Queue가 비어 있습니다
# >> 1
# 데이터 :
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 13
#      11 if menu == 0: break
#      12 elif menu == 1: # enqueue
# ---> 13     data = int(input('데이터 :'))
#      14     queue. append(data)
#      15 elif menu == 2: # dequeue
#
# ValueError: invalid literal for int() with base 10: ''

# %%
from collections import deque
queue = deque()

def enqueue(data):
    queue. append(data)

def dequeue():
    if queue:
        data = queue. popleft()
    else:
        data = -1
    return data

def getFront():
    if queue: return queue[0]
    return -1

print('시작')

while True:
# 메뉴 프린트
# 메뉴 번호 입력
    menu = int(input('>>'))
    if menu == 0: break
    elif menu == 1: # enqueue
        data = int(input('데이터 :'))
        enqueue (data)

    elif menu == 2: # dequeue
        data = dequeue()
        if data != -1:
            print('가져온 데이터 :', data)
        else:
            print('Queue가 비어 있습니다')

    elif menu == 3: # peek
        data = getFront ()
        if data != -1:
            print(data)
        else:
            print('Queue가 비어 있습니다')

    print(queue)

print('종료')
# Out:
# 시작
